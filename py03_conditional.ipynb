# %% [markdown]
# # else가 없는 조건문
#
# ```
# if 조건식:
#     조건식이 참일 때 실행할 코드 (블록)
# ```
#
# * `if 조건식` 뒤에는 반드시 콜론(:)을 사용해야 함.
# * `if` 블록(조건식이 참일 때 실행하는 문장들)은 반드시 **같은 크기로 ** 들여쓰기(identation)를 해야 함.

# %%
n = 100

# %%
if n > 0:
    print('양수')
    print('if 블록 끝')

print('if 바깥')
# Out:
# 양수
# if 블록 끝
# if 바깥

# %% [markdown]
# # else가 있는 조건문
#
# ```
# if 조건식:
#     조건식이 참일 때 실행할 코드 블록
# else:
#     조건식이 거짓일 때 실행할 코드 블록
#
# ```

# %%
n = int(input('정수 입력>>> '))
if n % 2: # 정수 n을 2로 나눈 나머지가 있으면(나머지가 0이 아니면)
    print('홀수') # (1)
else:
    print('짝수') # (2)
# Out:
# 정수 입력>>> 122
# 짝수

# %% [markdown]
# Python에서 참(Ture)으로 취급하는 것들:
#
# * 0이 아닌 숫자들
# * 1개 이상의 글자를 가지고 있는 문자열
# * 1개 이상의 원소를 가지고 있는 리스트, ...

# %% [markdown]
# # chained conditional
# ```
# if 조건식1:
#     조건식1이 참일 떄 실행할 코드 블록
# elif 조건식2
#     ...
# else:
#     위의 모든 조건식들을 만족하지 못할 떄 실행할 코드 블록
# ```
