# %% [markdown]
# <a href="https://colab.research.google.com/github/JMYoon90/JM_python/blob/main/py20_gapminder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * GitHub에 저장된 [gapminder.tsv](https://github.com/JakeOh/202208_itw_java134_lab_python/raw/main/gapminder.tsv) 파일을 읽고 DataFrame을 생성
# * 데이터 프레임 탐색
# * (중복되지 않는) 국가 이름의 개수?
# * (중복되지 않는) 대륙 이름?
# * (중복되지 않는) 연도의 개수?
# * 국가이름, 연도, 1인당 GDP 컬럼을 선택
# * 1인당 GDP의 최댓값, 최솟값을 찾고, 그 row를 출력
# * 기대수명(lifeExp)의 최솟값과 최댓값을 찾고, 그 행들을 출력
# * 연도별 기대수명의 평균을 출력
# * 연도별 1인당 GDP의 평균을 출력
# * 연도별 대륙별 전세계 인구를 출력

# %%
import pandas as pd
import seaborn as sns

# %%
file_path = 'https://github.com/JakeOh/202208_itw_java134_lab_python/raw/main/gapminder.tsv'

# %%
gapm = pd.read_csv(file_path, sep = '\t')

# %%
# 데이터 프레임 탐색
gapm
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 국가 이름 개수?
s = gapm['country'].unique()
print(len(s))
# Out:
# 142

# %%
# 대륙 이름?
for s in gapm['continent'].unique():
    print(s)
# Out:
# Asia
# Europe
# Africa
# Americas
# Oceania

# %%
# 연도의 개수?
s = gapm['year'].unique()
print(len(s))
print(s)
# Out:
# 12
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]

# %%
# 국가이름, 연도, 1인당 GDP 컬럼을 선택
gapm[['country', 'year', 'gdpPercap']]
# Out:
#           country  year   gdpPercap
# 0     Afghanistan  1952  779.445314
# 1     Afghanistan  1957  820.853030
# 2     Afghanistan  1962  853.100710
# 3     Afghanistan  1967  836.197138
# 4     Afghanistan  1972  739.981106
# ...           ...   ...         ...
# 1699     Zimbabwe  1987  706.157306
# 1700     Zimbabwe  1992  693.420786
# 1701     Zimbabwe  1997  792.449960
# 1702     Zimbabwe  2002  672.038623
# 1703     Zimbabwe  2007  469.709298
#
# [1704 rows x 3 columns]

# %%
# 1인당 GDP의 최댓값, 최솟값을 찾고, 그 row를 출력
gapm[(gapm['gdpPercap'] == gapm['gdpPercap'].min()) |
     (gapm['gdpPercap'] == gapm['gdpPercap'].max())
]
# Out:
#               country continent  year  lifeExp       pop      gdpPercap
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852     241.165876
# 853            Kuwait      Asia  1957   58.033    212846  113523.132900

# %%
# 기대수명(lifeExp)의 최솟값과 최댓값을 찾고, 그 행들을 출력
gapm[(gapm['lifeExp'] == gapm['lifeExp'].min()) |
     (gapm['lifeExp'] == gapm['lifeExp'].max())
]
# Out:
#      country continent  year  lifeExp        pop     gdpPercap
# 803    Japan      Asia  2007   82.603  127467972  31656.068060
# 1292  Rwanda    Africa  1992   23.599    7290203    737.068595

# %%
# 연도별 기대수명의 평균을 출력
for s in gapm['year'].unique():
    print(s, ' 년도 기대수명 평균 : ', gapm['lifeExp'][gapm['year'] == s].mean())
# Out:
# 1952  년도 기대수명 평균 :  49.057619718309866
# 1957  년도 기대수명 평균 :  51.50740112676056
# 1962  년도 기대수명 평균 :  53.609249014084504
# 1967  년도 기대수명 평균 :  55.678289577464795
# 1972  년도 기대수명 평균 :  57.64738647887324
# 1977  년도 기대수명 평균 :  59.57015746478874
# 1982  년도 기대수명 평균 :  61.53319718309859
# 1987  년도 기대수명 평균 :  63.21261267605633
# 1992  년도 기대수명 평균 :  64.16033802816901
# 1997  년도 기대수명 평균 :  65.01467605633802
# 2002  년도 기대수명 평균 :  65.69492253521126
# 2007  년도 기대수명 평균 :  67.00742253521126

# %%
# 연도별 1인당 GDP의 평균을 출력
for s in gapm['year'].unique():
    print(s, ' 년도 GDP 평균 : ', gapm['gdpPercap'][gapm['year'] == s].mean())
# Out:
# 1952  년도 GDP 평균 :  3725.276045801408
# 1957  년도 GDP 평균 :  4299.408344876057
# 1962  년도 GDP 평균 :  4725.812341961972
# 1967  년도 GDP 평균 :  5483.653046835212
# 1972  년도 GDP 평균 :  6770.082815282394
# 1977  년도 GDP 평균 :  7313.166420794366
# 1982  년도 GDP 평균 :  7518.901672698592
# 1987  년도 GDP 평균 :  7900.920217940845
# 1992  년도 GDP 평균 :  8158.608520688734
# 1997  년도 GDP 평균 :  9090.175363102111
# 2002  년도 GDP 평균 :  9917.848364685915
# 2007  년도 GDP 평균 :  11680.071819878167

# %%
# 연도별 대륙별 전세계 인구를 출력
for y in gapm['year'].unique():
    print('----------', y, '----------')
    for c in gapm['continent'].unique():
        print(y, ' 년도,', c, ' 대륙 인구 :  ',  gapm['gdpPercap'][gapm['year'] == y][gapm['continent'] == c].sum())
# Out:
# ---------- 1952 ----------
# 1952  년도, Asia  대륙 인구 :   171450.9721333
# 1952  년도, Europe  대륙 인구 :   169831.72304279997
# 1952  년도, Africa  대륙 인구 :   65133.7682227
# 1952  년도, Americas  대륙 인구 :   101976.563805
# 1952  년도, Oceania  대륙 인구 :   20596.1713
# ---------- 1957 ----------
# 1957  년도, Asia  대륙 인구 :   190995.1870181
# 1957  년도, Europe  대륙 인구 :   208890.38447800002
# 1957  년도, Africa  대륙 인구 :   72032.27523730001
# 1957  년도, Americas  대륙 인구 :   115401.09332900001
# 1957  년도, Oceania  대륙 인구 :   23197.04491
# ---------- 1962 ----------
# 1962  년도, Asia  대륙 인구 :   189069.1976176
# 1962  년도, Europe  대륙 인구 :   250964.604429
# 1962  년도, Africa  대륙 인구 :   83100.098892
# 1962  년도, Americas  대륙 인구 :   122538.54676
# 1962  년도, Oceania  대륙 인구 :   25392.904860000002
